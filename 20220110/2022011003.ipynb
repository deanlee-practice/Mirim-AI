# %%
import numpy as np

# %% [markdown]
# # NumPy 상수
# - 영(Zero)
# - 무한대(최대값)
# - 파이
# - 모르는 값

# %% [markdown]
# # 영(Zero)
# - 정수
# - 실수:
#   - 0.0

# %%
0
# Out:
# 0

# %%
0.0
# Out:
# 0.0

# %%
np.PZERO
# Out:
# 0.0

# %%
np.NZERO
# Out:
# -0.0

# %%
-0.0
# Out:
# -0.0

# %%
np.NZERO == -0.0
# Out:
# True

# %% [markdown]
# # 무한대
# - +무한대: inf, PINF, Inf, Infinity, infty
# - -무한대: NINF

# %%
np.inf
# Out:
# inf

# %%
np.NINF
# Out:
# -inf

# %%
np.PINF == np.inf
# Out:
# True

# %%
-np.inf == np.NINF
# Out:
# True

# %% [markdown]
# # 파이(PI)

# %%
np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# # 모르는 값 (Not A Number)
# - 정수: 없음.
# - 실수:
#   - numpy.nan
#   - numpy.NaN
#   - numpy.NAN

# %%
np.nan
# Out:
# nan

# %%
np.NaN
# Out:
# nan

# %%
np.NAN
# Out:
# nan

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
np.array([None, 3, 3.14], dtype=np.float64)
# Out:
# array([ nan, 3.  , 3.14])

# %%
np.array([None, 3, 3.14], dtype=np.int64)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-988d3d4d0c48> in <module>()
# ----> 1 np.array([None, 3, 3.14], dtype=np.int64)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
np.nan + np.nan
# Out:
# nan

# %%
np.nan * 3
# Out:
# nan

# %%
np.inf + np.inf
# Out:
# inf

# %%
np.inf - np.inf
# Out:
# nan

# %%
np.inf + 3
# Out:
# inf
