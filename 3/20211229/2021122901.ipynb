# %% [markdown]
# # dict
# - dict
# - key, value, (key, value)
# - methods

# %%
my_set = set()
my_set
# Out:
# set()

# %%
my_dict = {}
my_dict
# Out:
# {}

# %%
my_dict = dict()
my_dict
# Out:
# {}

# %%
my_dict = dict(a=100, b=200, c=300, d=400)
my_dict
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400}

# %%
my_dict = dict(**my_dict) # == dict(a=100, b=200, c=300, d=400)
my_dict
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400}

# %%
my_dict = dict({'a': 100,
                'b': 200,
                'c': 300,
                'd': 400})
my_dict
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400}

# %% [markdown]
# # dict의 연산

# %%
my_dict['a'] = -100
my_dict
# Out:
# {'a': -100, 'b': 200, 'c': 300, 'd': 400}

# %%
my_dict['e'] = 500
my_dict
# Out:
# {'a': -100, 'b': 200, 'c': 300, 'd': 400, 'e': 500}

# %%
my_dict['b'] = -200
my_dict
# Out:
# {'a': -100, 'b': -200, 'c': 300, 'd': 400, 'e': 500}

# %%
del my_dict['b']
my_dict
# Out:
# {'a': -100, 'c': 300, 'd': 400, 'e': 500}

# %% [markdown]
# # CURD
# - Create
# - Retrieve (Get)
#   - Retrieve
#   - List
# - Update
# - Delete
#
# # Web
# - Create - POST
# - Reteive:
#   - Retrieve - GET
#   - List - GET
# - Update - PUT, PATCH, (POST)
# - Delete - DELETE, (POST)

# %% [markdown]
# # dict 메서드
# - keys(), values(), items()
# - get()
# - update()

# %%
'a' in my_dict
# Out:
# True

# %%
'a' in my_dict.keys() # students,keys()
# Out:
# True

# %%
my_dict.keys()
# Out:
# dict_keys(['a', 'c', 'd', 'e'])

# %%
my_keys = list(my_dict.keys())
my_keys
# Out:
# ['a', 'c', 'd', 'e']

# %%
my_dict.values()
# Out:
# dict_values([-100, 300, 400, 500])

# %%
my_dict.items()
# Out:
# dict_items([('a', -100), ('c', 300), ('d', 400), ('e', 500)])

# %%
for key, value in my_dict.items():
  print(f"{key} = {value}")
# Out:
# a = -100
# c = 300
# d = 400
# e = 500

# %%
my_dict.get('a')
# Out:
# -100

# %%
print(my_dict.get('f')) # == my_dict.get('f', None)
# Out:
# None

# %%
my_dict.get('f', 0)
# Out:
# 0

# %%
my_dict.get('page', 1)
# Out:
# 1

# %%
my_dict.update({'a': -1000, 'z': 200})
my_dict
# Out:
# {'a': -1000, 'c': 300, 'd': 400, 'e': 500, 'z': 200}

# %%
# %%timeit
values = [i for i in range(10000)]
# Out:
# 1000 loops, best of 5: 431 µs per loop
