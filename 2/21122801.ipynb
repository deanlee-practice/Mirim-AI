# %% [markdown]
# # 문자(나)열
# - 작은 따옴표(''), 큰 따옴표("") 감싸져있는 값
#
# # 문자열의 메소드
#
# - 문자 찾기
#   - 접미사 접두사
# - 문자열 변경
# - 공백 제거하기

# %%
my_str = "Python"
my_str
# Out:
# 'Python'

# %%
dir(my_str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %% [markdown]
# # 문자 찾기
#
# - String.find
# - String.index
# - String.count

# %%
my_str.find("o")
# Out:
# 4

# %%
my_str.index("o")
# Out:
# 4

# %%
my_str.count("o")
# Out:
# 1

# %%
my_str.find("on3")
# Out:
# -1

# %%
my_str.index("on3")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-0a21d2ca7ab4> in <module>()
# ----> 1 my_str.index("on3")
#
# ValueError: substring not found

# %% [markdown]
# # 접미사와 접두사
# - String.startswith
# - String.endswith

# %%
my_str1 = "Cython"

# %%
my_str.startswith("Py")
# Out:
# True

# %%
my_str1.startswith("Cy")
# Out:
# True

# %%
my_str2, my_str3 = "Python2", "Python3"

# %%
my_str2.endswith("2")
# Out:
# True

# %%
my_str3.endswith("n3")
# Out:
# True

# %%
mail = "3XXX4XX"

# %%
mail.find("4")
# Out:
# 4

# %%
"4" in mail
# Out:
# True

# %% [markdown]
# # 소문자, 대문자
# - String.lower()
# - String.upper()
# - String.capitalize()

# %%
my_str = "pYthoN"

# %%
my_str.find("y") != -1 or my_str.find("Y") !=  -1
# Out:
# True

# %%
"y" in my_str or "Y" in my_str
# Out:
# True

# %%
"y" in my_str.lower()
# Out:
# True

# %%
"Y" in my_str.upper()
# Out:
# True

# %%
my_str.capitalize()
# Out:
# 'Python'

# %% [markdown]
# # 공백 제거하기
# - String.strip()

# %%
my_str = "    Python      "

# %%
my_str.strip()
# Out:
# 'Python'

# %% [markdown]
# # 문자열 나누기
# - String.split()
# - 문자열 -> 문자열의 리스트

# %%
my_csv = "New York, Central Park, China Town, Empire State Bld, Times Square"

# %%
my_csv.split(",")
# Out:
# ['New York',
#  ' Central Park',
#  ' China Town',
#  ' Empire State Bld',
#  ' Times Square']

# %%
my_csv.split(",")[-1].strip()
# Out:
# 'Times Square'

# %%
my_csv
# Out:
# 'New York, Central Park, China Town, Empire State Bld, Times Square'

# %% [markdown]
# # 문자열 바꾸기
# - String.replace(old, new)

# %%
my_str.replace("Py", "Cy")
# Out:
# '    Cython      '

# %%
my_str.replace("P", "C")
# Out:
# '    Cython      '

# %%
my_str.replace(" ", "")
# Out:
# 'Python'

# %%
my_str.replace("P", "")
# Out:
# '    ython      '

# %%
my_str.replace(" ", "").replace("P", "C")
# Out:
# 'Cython'
