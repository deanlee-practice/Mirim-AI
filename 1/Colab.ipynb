# %% [markdown]
# # ipynb
#
# ## 파일 저장
# - Ctrl + S
#
# # Cell(셀)
# - Code (Python, R, C++)
# - Text (Markdown)
#
# ## 셀실행
# - 왼쪽 실행 버튼
# - Ctrl + Enter
# - Shift + Enter
#   - 코드셀 추가 + 커서를 옮김
# - Ctrl + F9
#
# ## 셀추가
# - 왼쪽 상단
# - 셀의 아래쪽
# - Ctrl + M + B(elow)
# - Ctrl + M + A(ppend)
#
# ## 셀삭제
# - Ctrl + M + D(elete)
#
# ## 셀전환
# - 코드셀->텍스트셀: Ctrl + M + M
# - 텍스트셀->코드셀: Ctrl + M + Y

# %%
# Ctrl + M + A

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
# Ctrl + M + B

# %%
print("Hello, World")
# Out:
# Hello, World
