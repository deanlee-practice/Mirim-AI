# %% [markdown]
# # 문자(나)열 (String)
# > 정의
# >
# > 작은 따옴표('), 큰 따옴표(") 감싸져 있는 값.

# %%
"Hello, Python"
# Out:
# 'Hello, Python'

# %%
'Hello, Python'
# Out:
# 'Hello, Python'

# %%
import string

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.digits
# Out:
# '0123456789'

# %%
int("123")
# Out:
# 123

# %%
int("123c")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-5257e09f04e4> in <module>()
# ----> 1 int("123c")
#
# ValueError: invalid literal for int() with base 10: '123c'

# %%
string.hexdigits, string.octdigits
# Out:
# ('0123456789abcdefABCDEF', '01234567')

# %%
string.printable
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %% [markdown]
# # 이스케이핑(Escaping)

# %%
print("Hello, \b Bye")
# Out:
#  Bye

# %%
print(r"C:\nexon\resume") # raw string
# Out:
# C:\nexon\resume

# %% [markdown]
# # 멀티라인 문자열
# - """, ''' 로 감싼 값들
# - docstring

# %%
print("""
  1) 일어난다.
  2) 씻는다.
  3) 출근

""")
# Out:
#   1) 일어난다.
#   2) 씻는다.
#   3) 출근

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, start=0, /)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %% [markdown]
# # 문자열
# - 덧셈
# - 곱셈
# - 포함
# - 비교

# %%
"Hello," + " World"
# Out:
# 'Hello, World'

# %%
print("Hello"+"World")
# Out:
# HelloWorld

# %%
"Hello" + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-801ea13c8371> in <module>()
# ----> 1 "Hello" + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
"Hello" * 3
# Out:
# 'HelloHelloHello'

# %%
"Hello" * 0 # empty string
# Out:
# ''

# %%
"a"*3+"b"*2+"c"*5
# Out:
# 'aaabbccccc'

# %%
"He" in "Hello, world"
# Out:
# True

# %%
"h" in "Hello, world"
# Out:
# False

# %%
"Hello" == "Hello"
# Out:
# True

# %%
"hello" == "Hello"
# Out:
# False

# %% [markdown]
# # 인덱싱 (값 가져오기)
# - `[index]`: 문자를 가져온다.
# - my_str[3]: 4번째 문자(0부터)

# %%
my_str = "Python"

# %%
my_str[0]
# Out:
# 'P'

# %%
my_str[-1]
# Out:
# 'n'

# %%
my_str[5] # 안티 패턴
# Out:
# 'n'

# %%
my_str[len(my_str)-1] # 안티 패턴
# Out:
# 'n'

# %%
my_str[3] # 4번쨰
# Out:
# 'h'

# %%
my_str[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-a271e7f766ec> in <module>()
# ----> 1 my_str[10]
#
# IndexError: string index out of range

# %% [markdown]
# # 문자열의 슬라이싱
# - [start:end:step] start부터 end-1까지 step만큼 증가, 문자열을 반환

# %%
my_str[:2] # 첫글자부터 가져오기
# Out:
# 'Py'

# %%
my_str[0:2]
# Out:
# 'Py'

# %%
my_str[3:] # n부터 마지막까지
# Out:
# 'hon'

# %%
my_str
# Out:
# 'Python'

# %%
my_str[:]
# Out:
# 'Python'

# %%
my_str[::2] # Python
# Out:
# 'Pto'

# %%
my_str[1::2]
# Out:
# 'yhn'

# %%
my_str[::-1]
# Out:
# 'nohtyP'

# %%
my_str = string.ascii_lowercase
my_str
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
my_str[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-76547f658746> in <module>()
# ----> 1 my_str[100]
#
# IndexError: string index out of range

# %%
my_str[:100]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
my_str[0:3], my_str[3:6], my_str[6:9]
# Out:
# ('abc', 'def', 'ghi')

# %%
for i in range((len(my_str)//3) + 1):
  print(my_str[i*3:(i+1)*3])
# Out:
# abc
# def
# ghi
# jkl
# mno
# pqr
# stu
# vwx
# yz

# %%
n = 5
[my_str[i*n:(i+1)*n] for i in range((len(my_str)//n)+1)]
# Out:
# ['abcde', 'fghij', 'klmno', 'pqrst', 'uvwxy', 'z']

# %% [markdown]
# # 문자열의 길이
# - len

# %%
len(my_str)
# Out:
# 26

# %% [markdown]
# ## 공백이 포함된 문자열의 길이

# %%
my_str = "Python    "
len(my_str)
# Out:
# 10

# %%
len(my_str.strip())
# Out:
# 6

# %%
my_str = "Py      thon"
len(my_str.strip())
# Out:
# 12

# %%
len(my_str.replace(" ", ""))
# Out:
# 6

# %% [markdown]
# # 문자열 메소드
# - 메소드: 명령어
# - 문자 찾기
#   - 접두사와 접미사: 시작단어, 끝나는 단어
# - 문자열 변경
# - 공백 제거하기
# - 문자열 변경2
# - 문자열 포맷팅
# - 문자열 인코딩

# %%
my_str = "Python"

# %%
my_str[0] = "C"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-e274fcaf1696> in <module>()
# ----> 1 my_str[0] = "C"
#
# TypeError: 'str' object does not support item assignment

# %%
dir(my_str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %% [markdown]
# # 문자 찾기
# - String.count(sub)
# - String.find(sub)
# - String.index(sub)

# %%
my_str.count("P")
# Out:
# 1

# %%
my_str.count("Z")
# Out:
# 0

# %%
"aabbccc".count("c")
# Out:
# 3

# %%
my_str.find("y")
# Out:
# 1

# %%
my_str[1] # 첫번째 찾은 것이 나오는 위치
# Out:
# 'y'

# %%
"yyy".find("y")
# Out:
# 0

# %%
my_str.find("Y")
# Out:
# -1

# %%
my_str.index("y")
# Out:
# 1

# %%
my_str.index("Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-e2faeabb3226> in <module>()
# ----> 1 my_str.index("Y")
#
# ValueError: substring not found

# %% [markdown]
# # 접두사와 접미사
# - String.startswith(sub)
# - String.endswith(sub)

# %%
my_str.startswith("Py")
# Out:
# True

# %%
my_str.startswith("Cy")
# Out:
# False

# %%
my_str.endswith("on")
# Out:
# True

# %%
my_str.endswith("on3")
# Out:
# False

# %%
naver = "http://www.naver.com"

# %%
# http vs https
naver.startswith("https")
# Out:
# False

# %%
https_naver = "https://www.naver.com"
https_naver.startswith("https")
# Out:
# True

# %%
"HTTPS" if naver.startswith("https") else "HTTP"
# Out:
# 'HTTP'

# %%
female = "4XXXXXX"

# %%
female.startswith("4")
# Out:
# True

# %%
female.startswith("3")
# Out:
# False

# %%
female.find("4")
# Out:
# 0

# %% [markdown]
# # 소문자, 대문자, 첫글자를 대문자로(영문)
# - String.lower()
# - String.upper()
# - String.captialize()

# %%
my_str1 = "hello, WORLD"

# %%
my_str1.lower()
# Out:
# 'hello, world'

# %%
my_str1.upper()
# Out:
# 'HELLO, WORLD'

# %%
my_str1.capitalize()
# Out:
# 'Hello, world'

# %%
my_str1[0].upper() + my_str1[1:].lower()
# Out:
# 'Hello, world'

# %% [markdown]
# # 공백 제거하기
# - String.strip()
# - String.lstrip()
# - String.rstrip()

# %%
my_str2 = "     Pyth    on     "

# %%
my_str2.strip()
# Out:
# 'Pyth    on'

# %%
import string
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %%
my_str2.lstrip()
# Out:
# 'Pyth    on     '

# %%
my_str2.rstrip()
# Out:
# '     Pyth    on'

# %%
my_str2
# Out:
# '     Pyth    on     '

# %%
my_str2.lstrip().rstrip() # == my_str2.rstrip().lstrip() == my_str2.strip()
# Out:
# 'Pyth    on'

# %%
tmp = my_str2.lstrip()
print("\""+tmp+"\"")
result = tmp.rstrip()
result
# Out:
# "Pyth    on     "
# 'Pyth    on'

# %%
my_str[0]
# Out:
# 'P'

# %%
my_str[0] = "C"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-e274fcaf1696> in <module>()
# ----> 1 my_str[0] = "C"
#
# TypeError: 'str' object does not support item assignment

# %%
my_str.replace("P", "C")
# Out:
# 'Cython'

# %%
my_str3 = "Python, Python2, Python"
my_str3.replace("P", "C")
# Out:
# 'Cython, Cython2, Cython'

# %%
help(my_str3.replace)
# Out:
# Help on built-in function replace:
#
# replace(old, new, count=-1, /) method of builtins.str instance
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %%
my_str3.replace("P", "C", 1)
# Out:
# 'Cython, Python2, Python'

# %%
my_str3.replace("P", "C", 2)
# Out:
# 'Cython, Cython2, Python'

# %%
my_str3.replace("P", "C", -1)
# Out:
# 'Cython, Cython2, Cython'

# %% [markdown]
# # 문자열 나누기 (Split)
# - String.split(sep)

# %%
my_str3
# Out:
# 'Python, Python2, Python'

# %%
my_str3.split(',') # => list
# Out:
# ['Python', ' Python2', ' Python']

# %%
for s in my_str3.split(','):
  print(s.strip())
# Out:
# Python
# Python2
# Python

# %%
my_str4 = "My name is Iron Man"
my_str4
# Out:
# 'My name is Iron Man'

# %%
my_str4.split(" ")
# Out:
# ['My', 'name', 'is', 'Iron', 'Man']

# %%
my_str4.split()
# Out:
# ['My', 'name', 'is', 'Iron', 'Man']

# %%
my_str
# Out:
# 'Python'

# %%
my_str2.replace(" ", "")
# Out:
# 'Python'
