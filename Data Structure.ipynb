# %% [markdown]
# # 기본 데이터 구조
# - 리스트(list)
# - 튜플(tuple)
# - 집합(set)
# - 딕션너리(dict)

# %% [markdown]
# # 리스트

# %% [markdown]
# ## 리스트의 정의

# %%
my_list = list()
my_list
# Out:
# []

# %%
my_list = []
my_list
# Out:
# []

# %%
my_list = list(range(1, 10, 2))
my_list
# Out:
# [1, 3, 5, 7, 9]

# %%
my_list = list([1, 3, 5, 7, 9])
my_list
# Out:
# [1, 3, 5, 7, 9]

# %%
my_list = [1, 3, 5, 7, 9]
my_list
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# # 리스트의 연산
# - 덧셈
# - 곱셈
# - 포함(in)
# - 비교

# %%
[1, 3, 5] + [7, 9]
# Out:
# [1, 3, 5, 7, 9]

# %%
"Py" + "thon"
# Out:
# 'Python'

# %%
[1] * 5
# Out:
# [1, 1, 1, 1, 1]

# %%
"Bye" * 5
# Out:
# 'ByeByeByeByeBye'

# %%
[0,]
# Out:
# [0]

# %%
[0,] * 3
# Out:
# [0, 0, 0]

# %%
3 in my_list
# Out:
# True

# %%
4 in my_list
# Out:
# False

# %%
([1, 3, 5] + [7, 9]) == ([1, 3] + [5, 7, 9]) # both [1, 3, 5, 7, 9]
# Out:
# True

# %%
([1, 3, 5] + [7, 9]) == ([5, 7, 9] + [1, 3])
# Out:
# False

# %%
my_list = []
if my_list:
  print("There is an element.")
else:
  print("The list is empty.")
# Out:
# The list is empty.

# %%
my_list = [1, 3]
if my_list:
  print("There is an element.")
else:
  print("The list is empty.")
# Out:
# There is an element.

# %%
my_list = []

# %%
if not my_list:
  print("The list is empty.")
else:
  print("There is an element.")
# Out:
# The list is empty.

# %% [markdown]
# # 리스트의 길이
# - len()

# %%
my_list = [1, 3, 5, 7, 9]
len(my_list)
# Out:
# 5

# %%
my_list[len(my_list)-1] # 안티 패턴
# my_list[len(my_list)]
# Out:
# 9

# %%
my_list[len(my_list)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-d598c93259b0> in <module>()
# ----> 1 my_list[len(my_list)]
#
# IndexError: list index out of range

# %% [markdown]
# # 리스트의 인덱싱(값 가져오기)
# - `[index]` 인덱싱
# - 첫번째: my_list[0]
# - 마지막: my_list[-1]

# %%
my_list[0]
# Out:
# 1

# %%
my_list[-1]
# Out:
# 9

# %%
my_list[2]
# Out:
# 5

# %%
my_list[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-c8122f5945b8> in <module>()
# ----> 1 my_list[6]
#
# IndexError: list index out of range

# %%
for elem in my_list:
  print(elem)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i, elem in enumerate(my_list):
  print(f"{i}: {elem}")
# Out:
# 0: 1
# 1: 3
# 2: 5
# 3: 7
# 4: 9

# %%
my_str = "Python"
my_str[0]
# Out:
# 'P'

# %%
my_list[0] = 100
my_list
# Out:
# [100, 3, 5, 7, 9]

# %% [markdown]
# # 슬라이싱
# - [start:end:step]
# - 첫번째 값부터 n번째 값까지 [0:n](X) => [:n]
# - n번째 값부터 마지막 값까지 [n:]

# %%
# my_list[2] (x) 
# my_list[0], my_list[1] (o)
my_list[:2]
# Out:
# [100, 3]

# %%
my_list[2:]
# Out:
# [5, 7, 9]

# %%
my_list[:] # 전체 리스트 (my_list)
# Out:
# [100, 3, 5, 7, 9]

# %%
my_list2 = my_list[:]
my_list2
# Out:
# [100, 3, 5, 7, 9]

# %%
my_list2[2] = 500
my_list2
# Out:
# [100, 3, 500, 7, 9]

# %%
my_list
# Out:
# [100, 3, 5, 7, 9]

# %%
my_list3 = my_list
my_list3
# Out:
# [100, 3, 5, 7, 9]

# %%
my_list3[2] = -500
my_list3
# Out:
# [100, 3, -500, 7, 9]

# %%
my_list
# Out:
# [100, 3, -500, 7, 9]

# %%
my_list[-1] = -900
my_list
# Out:
# [100, 3, -500, 7, -900]

# %%
my_list3
# Out:
# [100, 3, -500, 7, -900]

# %%
my_list = my_list2[:]
my_list
# Out:
# [100, 3, 500, 7, 9]

# %%
my_list4 = my_list.copy()
my_list4
# Out:
# [100, 3, 500, 7, 9]

# %% [markdown]
# # 리스트의 메소드
# - 리스트에 값추가
# - 값 찾기
# - 값 삭제
# - 리스트 복제
# - 리스트 정렬
# - 리스트의 역순

# %%
dir(my_list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# ## 값 추가
# - list.append()
# - list.insert()
# - list.extend()

# %%
my_list4
# Out:
# [100, 3, 500, 7, 9, 11]

# %%
my_list4.append(13)
my_list4
# Out:
# [100, 3, 500, 7, 9, 11, 13]

# %%
my_list4.append([15, 17])
my_list4
# Out:
# [100, 3, 500, 7, 9, 11, 13, [15, 17]]

# %%
for num in [15, 17]:
  my_list4.append(num)

# %%
my_list4
# Out:
# [100, 3, 500, 7, 9, 11, 13, [15, 17], 15, 17]

# %%
my_list4.extend([19, 21])

# %%
my_list4
# Out:
# [100, 3, 500, 7, 9, 11, 13, [15, 17], 15, 17, 19, 21]

# %%
my_list4 = my_list4 + [23, 25]
my_list4
# Out:
# [100, 3, 500, 7, 9, 11, 13, [15, 17], 15, 17, 19, 21, 23, 25]

# %%
my_list4.insert(0, 1000)
my_list4
# Out:
# [1000, 100, 3, 500, 7, 9, 11, 13, [15, 17], 15, 17, 19, 21, 23, 25]

# %% [markdown]
# # 값 찾기
# - list.index()
# - list.count()
# - list.pop()

# %%
my_list4
# Out:
# [1000, 100, 3, 500, 7, 9, 11, 13, [15, 17], 15, 17, 19, 21, 23, 25]

# %%
my_list4.index(1000)
# Out:
# 0

# %%
my_list4.index(23)
# Out:
# 13

# %%
my_list4.index(999)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-dc178b57b134> in <module>()
# ----> 1 my_list4.index(999)
#
# ValueError: 999 is not in list

# %%
my_list4.count(999)
# Out:
# 0

# %%
my_list4.count(1000)
# Out:
# 1

# %%
my_list4.pop()
# Out:
# 25

# %%
my_list4
# Out:
# [1000, 100, 3, 500, 7, 9, 11, 13, [15, 17], 15, 17, 19, 21, 23]

# %%
my_list4.pop()
# Out:
# 23

# %%
my_list4.pop(8)
# Out:
# [15, 17]

# %%
my_list4
# Out:
# [1000, 100, 3, 500, 7, 9, 11, 13, 15, 17, 19, 21]

# %% [markdown]
# # 리스트 삭제
# - 리스트 전체 삭제
#   - list.clear()
#   - my_list = []
# - 원소 삭제
#   - list.remove()
#   - list.pop()

# %%
my_list4
# Out:
# [1000, 100, 3, 500, 7, 9, 11, 13, 15, 17, 19, 21]

# %%
my_list4.remove(1000)
my_list4
# Out:
# [100, 3, 500, 7, 9, 11, 13, 15, 17, 19, 21]

# %%
my_list4.index(500)
# Out:
# 2

# %%
my_list4.pop(my_list4.index(500))
my_list4
# Out:
# [100, 3, 7, 9, 11, 13, 15, 17, 19, 21]

# %%
my_list4.clear()
my_list4
# Out:
# []

# %% [markdown]
# # 리스트의 역순
# - list.revers()
# - reversed()
# - my_list[::-1]

# %%
my_list3
# Out:
# [100, 3, -500, 7, -900]

# %%
my_list3[::-1] # 사용
# Out:
# [-900, 7, -500, 3, 100]

# %%
reversed(my_list3) # 사용 (속도 빠름)

# %%
list(reversed(my_list3))
# Out:
# [-900, 7, -500, 3, 100]

# %%
my_list3
# Out:
# [100, 3, -500, 7, -900]

# %%
my_list3.reverse() # 사용하지 않는다. # 원본 소실
my_list3
# Out:
# [-900, 7, -500, 3, 100]

# %% [markdown]
# # 정렬
# - list.sort()
# - sorted()

# %%
sorted(my_list3)
# Out:
# [-900, -500, 3, 7, 100]

# %%
my_list3
# Out:
# [-900, 7, -500, 3, 100]

# %%
sorted(my_list3)[::-1]
# Out:
# [100, 7, 3, -500, -900]

# %%
sorted(my_list3, reverse=True)
# Out:
# [100, 7, 3, -500, -900]

# %%
my_list3.sort()
my_list3
# Out:
# [-900, -500, 3, 7, 100]

# %% [markdown]
# # 튜플

# %%
my_tup = tuple()
my_tup
# Out:
# ()

# %%
my_tup = ()
my_tup
# Out:
# ()

# %%
my_tup = (0)
my_tup
# Out:
# 0

# %%
type(my_tup)
# Out:
# int

# %%
my_tup = (0,)
my_tup
# Out:
# (0,)

# %%
my_tup = tuple([1, 3, 5, 7, 9])
my_tup
# Out:
# (1, 3, 5, 7, 9)

# %%
my_tup = (1, 3, 5, 7, 9)
my_tup
# Out:
# (1, 3, 5, 7, 9)

# %%
my_tup = 1, 3, 5, 7, 9
my_tup
# Out:
# (1, 3, 5, 7, 9)

# %%
dir(my_list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(my_tup)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
my_list = ['apple', 'orange', 'banana']
my_list
# Out:
# ['apple', 'orange', 'banana']

# %%
my_tup = ('Michael', 26, 180)
my_tup
# Out:
# ('Michael', 26, 180)
